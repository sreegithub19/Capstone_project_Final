# %%
import matplotlib.pyplot as plt
   
Model = ['Auto_Colorization (CNN)','Node.js(deepai)','Python(deepai)','OpenCV(dnn)']
Time_taken = [4353515625000, 107675700,60468750000,4230250000000]   #in nanoseconds

print("                      Line chart")
print("           Image colorization models vs Time taken")
print("     The models have been tested on 1028 test/black-and-white images")
plt.plot(Model,Time_taken, color='red', marker='o')
#plt.title('Image colorization models vs Time taken', fontsize=14)
plt.xlabel('Image colorization models', fontsize=14)
plt.ylabel('Time taken(in nanoseconds)', fontsize=14)
plt.grid(True)
plt.show()
# Out:
#                       Line chart
#            Image colorization models vs Time taken
#      The models have been tested on 1028 test/black-and-white images
